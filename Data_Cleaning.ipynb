# %% [markdown]
# # Importamos funciones

# %%
import pandas as pd
import re
import src.cleaning as fs

# %% [markdown]
# # Cargamos csv para su análisis

# %%
df = pd.read_csv("input/houses_Madrid.csv", encoding= "utf-8")

# %% [markdown]
# ## Hacemos una primera exploración de los datos

# %%
df.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  21742              Piso en venta en calle de Godella, 64
# 1           1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2           2  21740               Piso en venta en calle del Talco, 68
# 3           3  21739               Piso en venta en calle Pedro Jiménez
# 4           4  21738  Piso en venta en carretera de Villaverde a Val...
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid         64.0          60.0        2          1.0
# 1    Los Ángeles, Madrid         70.0           NaN        3          1.0
# 2     San Andrés, Madrid         94.0          54.0        2          2.0
# 3     San Andrés, Madrid         64.0           NaN        2          1.0
# 4    Los Rosales, Madrid        108.0          90.0        2          2.0
#
#    n_floors  sq_mt_allotment  ...  energy_certificate  has_parking  \
# 0       NaN              NaN  ...                   D        False
# 1       NaN              NaN  ...          en trámite        False
# 2       NaN              NaN  ...         no indicado        False
# 3       NaN              NaN  ...          en trámite        False
# 4       NaN              NaN  ...          en trámite         True
#
#   has_private_parking  has_public_parking is_parking_included_in_price  \
# 0                 NaN                 NaN                          NaN
# 1                 NaN                 NaN                          NaN
# 2                 NaN                 NaN                          NaN
# 3                 NaN                 NaN                          NaN
# 4                 NaN                 NaN                         True
#
#   parking_price  is_orientation_north is_orientation_west  \
# 0           NaN                 False                True
# 1           NaN                   NaN                 NaN
# 2           NaN                   NaN                 NaN
# 3           NaN                 False               False
# 4           0.0                  True                True
#
#   is_orientation_south  is_orientation_east
# 0                False                False
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                 True                False
# 4                 True                 True
#
# [5 rows x 58 columns]

# %%
df.house_type_id.iloc[39:45]
# Out:
# 39     HouseType 1: Pisos
# 40    HouseType 4: Dúplex
# 41                    NaN
# 42     HouseType 1: Pisos
# 43     HouseType 1: Pisos
# 44     HouseType 1: Pisos
# Name: house_type_id, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'subtitle', 'sq_mt_built', 'sq_mt_useful',
#        'n_rooms', 'n_bathrooms', 'n_floors', 'sq_mt_allotment', 'latitude',
#        'longitude', 'raw_address', 'is_exact_address_hidden', 'street_name',
#        'street_number', 'portal', 'floor', 'is_floor_under', 'door',
#        'neighborhood_id', 'operation', 'rent_price', 'rent_price_by_area',
#        'is_rent_price_known', 'buy_price', 'buy_price_by_area',
#        'is_buy_price_known', 'house_type_id', 'is_renewal_needed',
#        'is_new_development', 'built_year', 'has_central_heating',
#        'has_individual_heating', 'are_pets_allowed', 'has_ac',
#        'has_fitted_wardrobes', 'has_lift', 'is_exterior', 'has_garden',
#        'has_pool', 'has_terrace', 'has_balcony', 'has_storage_room',
#        'is_furnished', 'is_kitchen_equipped', 'is_accessible',
#        'has_green_zones', 'energy_certificate', 'has_parking',
#        'has_private_parking', 'has_public_parking',
#        'is_parking_included_in_price', 'parking_price', 'is_orientation_north',
#        'is_orientation_west', 'is_orientation_south', 'is_orientation_east'],
#       dtype='object')

# %%
df.buy_price.unique()
# Out:
# array([ 85000, 129900, 144247, ..., 215750, 299800, 388000])

# %%
df.iloc[1]
# Out:
# Unnamed: 0                                                                      1
# id                                                                          21741
# title                            Piso en venta en calle de la del Manojo de Rosas
# subtitle                                                      Los Ángeles, Madrid
# sq_mt_built                                                                    70
# sq_mt_useful                                                                  NaN
# n_rooms                                                                         3
# n_bathrooms                                                                     1
# n_floors                                                                      NaN
# sq_mt_allotment                                                               NaN
# latitude                                                                      NaN
# longitude                                                                     NaN
# raw_address                                       Calle de la del Manojo de Rosas
# is_exact_address_hidden                                                      True
# street_name                                       Calle de la del Manojo de Rosas
# street_number                                                                 NaN
# portal                                                                        NaN
# floor                                                                           4
# is_floor_under                                                              False
# door                                                                          NaN
# neighborhood_id                 Neighborhood 132: Los Ángeles (1796.68 €/m2) -...
# operation                                                                    sale
# rent_price                                                                    666
# rent_price_by_area                                                            NaN
# is_rent_price_known                                                         False
# buy_price                                                                  129900
# buy_price_by_area                                                            1856
# is_buy_price_known                                                           True
# house_type_id                                                  HouseType 1: Pisos
# is_renewal_needed                                                            True
# is_new_development                                                          False
# built_year                                                                    NaN
# has_central_heating                                                           NaN
# has_individual_heating                                                        NaN
# are_pets_allowed                                                              NaN
# has_ac                                                                        NaN
# has_fitted_wardrobes                                                         True
# has_lift                                                                     True
# is_exterior                                                                  True
# has_garden                                                                    NaN
# has_pool                                                                      NaN
# has_terrace                                                                  True
# has_balcony                                                                   NaN
# has_storage_room                                                              NaN
# is_furnished                                                                  NaN
# is_kitchen_equipped                                                           NaN
# is_accessible                                                                 NaN
# has_green_zones                                                               NaN
# energy_certificate                                                     en trámite
# has_parking                                                                 False
# has_private_parking                                                           NaN
# has_public_parking                                                            NaN
# is_parking_included_in_price                                                  NaN
# parking_price                                                                 NaN
# is_orientation_north                                                          NaN
# is_orientation_west                                                           NaN
# is_orientation_south                                                          NaN
# is_orientation_east                                                           NaN
# Name: 1, dtype: object

# %% [markdown]
# ### Comprobamos que no hayan filas duplicadas

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (21742, 58)

# %%
df["subtitle"] = df.subtitle.apply(lambda x: x.split(",")[0])

# %%
df.subtitle.value_counts()
# Out:
# Chamartín                           851
# Moncloa                             771
# Chamberí                            583
# Centro                              552
# Hortaleza                           503
#                                    ...
# Barajas                               7
# Campo de las Naciones-Corralejos      6
# Casco Histórico de Barajas            5
# Timón                                 4
# Cuatro Vientos                        2
# Name: subtitle, Length: 146, dtype: int64

# %%
df.house_type_id.unique()
# Out:
# array(['HouseType 1: Pisos', 'HouseType 4: Dúplex', nan,
#        'HouseType 5: Áticos', 'HouseType 2: Casa o chalet'], dtype=object)

# %%
df.is_new_development.unique()
# Out:
# array([False, nan, True], dtype=object)

# %% [markdown]
# ## Seleccionamos las columnas que nos interesan para proceder a la limpieza de los datos

# %%
df2 = df[["subtitle", "sq_mt_built", "n_rooms", "n_bathrooms", "neighborhood_id", "buy_price", "buy_price_by_area", "is_new_development", "house_type_id", "has_garden", "has_pool","has_parking"]]

# %%
df2.head(10)
# Out:
#         subtitle  sq_mt_built  n_rooms  n_bathrooms  \
# 0  San Cristóbal         64.0        2          1.0
# 1    Los Ángeles         70.0        3          1.0
# 2     San Andrés         94.0        2          2.0
# 3     San Andrés         64.0        2          1.0
# 4    Los Rosales        108.0        2          2.0
# 5     San Andrés        126.0        4          2.0
# 6     San Andrés        120.0        5          2.0
# 7     Villaverde        125.0        3          2.0
# 8     Villaverde         84.0        3          2.0
# 9    Los Rosales         85.0        2          1.0
#
#                                      neighborhood_id  buy_price  \
# 0  Neighborhood 135: San Cristóbal (1308.89 €/m2)...      85000
# 1  Neighborhood 132: Los Ángeles (1796.68 €/m2) -...     129900
# 2  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     144247
# 3  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     109900
# 4  Neighborhood 133: Los Rosales (1827.79 €/m2) -...     260000
# 5  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     195000
# 6  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     190000
# 7  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     198500
# 8  Neighborhood 131: Butarque (2197.8 €/m2) - Dis...     212000
# 9  Neighborhood 133: Los Rosales (1827.79 €/m2) -...     131400
#
#    buy_price_by_area is_new_development       house_type_id has_garden  \
# 0               1328              False  HouseType 1: Pisos        NaN
# 1               1856              False  HouseType 1: Pisos        NaN
# 2               1535              False  HouseType 1: Pisos        NaN
# 3               1717              False  HouseType 1: Pisos        NaN
# 4               2407              False  HouseType 1: Pisos        NaN
# 5               1548              False  HouseType 1: Pisos        NaN
# 6               1583              False  HouseType 1: Pisos        NaN
# 7               1588              False  HouseType 1: Pisos        NaN
# 8               2524              False  HouseType 1: Pisos        NaN
# 9               1546              False  HouseType 1: Pisos        NaN
#
#   has_pool  has_parking
# 0      NaN        False
# 1      NaN        False
# 2      NaN        False
# 3      NaN        False
# 4     True         True
# 5      NaN         True
# 6     True         True
# 7      NaN        False
# 8     True         True
# 9      NaN        False

# %%
df2.isnull().sum()
# Out:
# subtitle                  0
# sq_mt_built             126
# n_rooms                   0
# n_bathrooms              16
# neighborhood_id           0
# buy_price                 0
# buy_price_by_area         0
# is_new_development      992
# house_type_id           391
# has_garden            20186
# has_pool              16571
# has_parking               0
# dtype: int64

# %%
df2.shape
# Out:
# (21742, 12)

# %% [markdown]
# ### Eliminamos las filas con valores nulos y rellenamos las que nos interesa conservar

# %%
df2 = df2.dropna(axis=0, subset=["sq_mt_built", "is_new_development", "house_type_id", "n_bathrooms"])

# %%
df2.shape
# Out:
# (20238, 12)

# %%
df2["has_garden"] = df2.has_garden.fillna("False")

# %%
df2["has_pool"] = df2.has_pool.fillna("False")

# %%
df2.isnull().sum()
# Out:
# subtitle              0
# sq_mt_built           0
# n_rooms               0
# n_bathrooms           0
# neighborhood_id       0
# buy_price             0
# buy_price_by_area     0
# is_new_development    0
# house_type_id         0
# has_garden            0
# has_pool              0
# has_parking           0
# dtype: int64

# %% [markdown]
# ## Realizamos la limpieza de los datos aplicando funciones para ellos

# %%
df2["numero_barrio"] = df.neighborhood_id.apply(fs.neighborhood)

# %%
df2["barrio"] = df.neighborhood_id.apply(fs.barrio)

# %%
df2["tipo"] = df2.house_type_id.apply(fs.house_type)

# %%
df2.neighborhood_id.iloc[8]
# Out:
# 'Neighborhood 131: Butarque (2197.8 €/m2) - District 21: Villaverde'

# %%
df2["eurosm2"] = df.neighborhood_id.apply(fs.euro_m2)

# %%
df2["numero_distrito"] = df2.neighborhood_id.apply(fs.n_distrito)

# %%
df2["distrito"] = df2.neighborhood_id.apply(lambda x: x.split(":")[2].strip())

# %% [markdown]
# #### Aqui relleno las columnas buy_price_by_area y eurosm2 con un valor orientativo de 1500 ya que no quiero perder unos 200 pisos simplemente por no tener el valor promedio del m2 construido.

# %%
df2["buy_price_by_area"] = df2.buy_price_by_area.apply(lambda x: 1500 if "Neighborhood" in str(x) else x)

# %%
df2["eurosm2"] = df2.eurosm2.apply(lambda x: 1500 if "Neighborhood" in str(x) else x)

# %%
df2.head(10)
# Out:
#         subtitle  sq_mt_built  n_rooms  n_bathrooms  \
# 0  San Cristóbal         64.0        2          1.0
# 1    Los Ángeles         70.0        3          1.0
# 2     San Andrés         94.0        2          2.0
# 3     San Andrés         64.0        2          1.0
# 4    Los Rosales        108.0        2          2.0
# 5     San Andrés        126.0        4          2.0
# 6     San Andrés        120.0        5          2.0
# 7     Villaverde        125.0        3          2.0
# 8     Villaverde         84.0        3          2.0
# 9    Los Rosales         85.0        2          1.0
#
#                                      neighborhood_id  buy_price  \
# 0  Neighborhood 135: San Cristóbal (1308.89 €/m2)...      85000
# 1  Neighborhood 132: Los Ángeles (1796.68 €/m2) -...     129900
# 2  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     144247
# 3  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     109900
# 4  Neighborhood 133: Los Rosales (1827.79 €/m2) -...     260000
# 5  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     195000
# 6  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     190000
# 7  Neighborhood 134: San Andrés (1617.18 €/m2) - ...     198500
# 8  Neighborhood 131: Butarque (2197.8 €/m2) - Dis...     212000
# 9  Neighborhood 133: Los Rosales (1827.79 €/m2) -...     131400
#
#    buy_price_by_area is_new_development       house_type_id has_garden  \
# 0               1328              False  HouseType 1: Pisos      False
# 1               1856              False  HouseType 1: Pisos      False
# 2               1535              False  HouseType 1: Pisos      False
# 3               1717              False  HouseType 1: Pisos      False
# 4               2407              False  HouseType 1: Pisos      False
# 5               1548              False  HouseType 1: Pisos      False
# 6               1583              False  HouseType 1: Pisos      False
# 7               1588              False  HouseType 1: Pisos      False
# 8               2524              False  HouseType 1: Pisos      False
# 9               1546              False  HouseType 1: Pisos      False
#
#   has_pool  has_parking     numero_barrio         barrio   tipo  eurosm2  \
# 0    False        False  Neighborhood 135  San Cristóbal  Pisos  1308.89
# 1    False        False  Neighborhood 132    Los Ángeles  Pisos  1796.68
# 2    False        False  Neighborhood 134     San Andrés  Pisos  1617.18
# 3    False        False  Neighborhood 134     San Andrés  Pisos  1617.18
# 4     True         True  Neighborhood 133    Los Rosales  Pisos  1827.79
# 5    False         True  Neighborhood 134     San Andrés  Pisos  1617.18
# 6     True         True  Neighborhood 134     San Andrés  Pisos  1617.18
# 7    False        False  Neighborhood 134     San Andrés  Pisos  1617.18
# 8     True         True  Neighborhood 131       Butarque  Pisos   2197.8
# 9    False        False  Neighborhood 133    Los Rosales  Pisos  1827.79
#
#   numero_distrito    distrito
# 0     District 21  Villaverde
# 1     District 21  Villaverde
# 2     District 21  Villaverde
# 3     District 21  Villaverde
# 4     District 21  Villaverde
# 5     District 21  Villaverde
# 6     District 21  Villaverde
# 7     District 21  Villaverde
# 8     District 21  Villaverde
# 9     District 21  Villaverde

# %% [markdown]
# ## Generamos el dataframe definitivo

# %%
df_clean = df2[["distrito", "numero_distrito", "barrio",  "numero_barrio", "tipo", "is_new_development", "sq_mt_built", "n_rooms", "n_bathrooms", "has_garden", "has_pool","has_parking", "buy_price", "buy_price_by_area", "eurosm2"]]

# %%
df_clean.head(10)
# Out:
#      distrito numero_distrito         barrio     numero_barrio   tipo  \
# 0  Villaverde     District 21  San Cristóbal  Neighborhood 135  Pisos
# 1  Villaverde     District 21    Los Ángeles  Neighborhood 132  Pisos
# 2  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 3  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 4  Villaverde     District 21    Los Rosales  Neighborhood 133  Pisos
# 5  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 6  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 7  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 8  Villaverde     District 21       Butarque  Neighborhood 131  Pisos
# 9  Villaverde     District 21    Los Rosales  Neighborhood 133  Pisos
#
#   is_new_development  sq_mt_built  n_rooms  n_bathrooms has_garden has_pool  \
# 0              False         64.0        2          1.0      False    False
# 1              False         70.0        3          1.0      False    False
# 2              False         94.0        2          2.0      False    False
# 3              False         64.0        2          1.0      False    False
# 4              False        108.0        2          2.0      False     True
# 5              False        126.0        4          2.0      False    False
# 6              False        120.0        5          2.0      False     True
# 7              False        125.0        3          2.0      False    False
# 8              False         84.0        3          2.0      False     True
# 9              False         85.0        2          1.0      False    False
#
#    has_parking  buy_price  buy_price_by_area  eurosm2
# 0        False      85000               1328  1308.89
# 1        False     129900               1856  1796.68
# 2        False     144247               1535  1617.18
# 3        False     109900               1717  1617.18
# 4         True     260000               2407  1827.79
# 5         True     195000               1548  1617.18
# 6         True     190000               1583  1617.18
# 7        False     198500               1588  1617.18
# 8         True     212000               2524   2197.8
# 9        False     131400               1546  1827.79

# %%
df_clean.shape
# Out:
# (20238, 15)

# %% [markdown]
# ### Renombramos las columnas para una mejor comprensión de los datos

# %%
df_clean.columns = ["distrito", "numero_distrito", "barrio",  "numero_barrio", "tipo", "nueva_construccion", "metros2_const", "n_habitaciones", "n_banos", "jardin", "piscina","parking", "precio_venta", "eurosm2_distrito" ,"eurosm2_barrio"]

# %%
df_clean.head(10)
# Out:
#      distrito numero_distrito         barrio     numero_barrio   tipo  \
# 0  Villaverde     District 21  San Cristóbal  Neighborhood 135  Pisos
# 1  Villaverde     District 21    Los Ángeles  Neighborhood 132  Pisos
# 2  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 3  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 4  Villaverde     District 21    Los Rosales  Neighborhood 133  Pisos
# 5  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 6  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 7  Villaverde     District 21     San Andrés  Neighborhood 134  Pisos
# 8  Villaverde     District 21       Butarque  Neighborhood 131  Pisos
# 9  Villaverde     District 21    Los Rosales  Neighborhood 133  Pisos
#
#   nueva_construccion  metros2_const  n_habitaciones  n_banos jardin piscina  \
# 0              False           64.0               2      1.0  False   False
# 1              False           70.0               3      1.0  False   False
# 2              False           94.0               2      2.0  False   False
# 3              False           64.0               2      1.0  False   False
# 4              False          108.0               2      2.0  False    True
# 5              False          126.0               4      2.0  False   False
# 6              False          120.0               5      2.0  False    True
# 7              False          125.0               3      2.0  False   False
# 8              False           84.0               3      2.0  False    True
# 9              False           85.0               2      1.0  False   False
#
#    parking  precio_venta  eurosm2_distrito eurosm2_barrio
# 0    False         85000              1328        1308.89
# 1    False        129900              1856        1796.68
# 2    False        144247              1535        1617.18
# 3    False        109900              1717        1617.18
# 4     True        260000              2407        1827.79
# 5     True        195000              1548        1617.18
# 6     True        190000              1583        1617.18
# 7    False        198500              1588        1617.18
# 8     True        212000              2524         2197.8
# 9    False        131400              1546        1827.79

# %%
df_clean.shape
# Out:
# (20238, 15)

# %% [markdown]
# ## Exportamos el csv definitivo para su posterior análisis

# %%
df_clean.to_csv("output/clean_csv.csv", index = False)
